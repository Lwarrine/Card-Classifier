# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from dataset.dataloader1 import PlayingCardDataset
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt

# %%
train_loader, test_loader, val_loader = PlayingCardDataset.get_data_loaders(batch_size = 5)
for images, labels in train_loader:
    break

# %%
plot_images = (images * 255.0)
plot_images = plot_images.numpy().transpose(0, 2, 3, 1).astype(np.uint8)
plt.figure(figsize=(15, 5))
plt.imshow(np.hstack(plot_images))
plt.savefig('../assets/train_batch.png')
plt.show()
print(f"Labels :{labels}")
# Out:
# Labels :tensor([5, 5, 2, 5, 5])

# %%
for images1, labels1 in test_loader:
    break
plot_images1 = (images1 * 255.0)
plot_images1 = plot_images1.numpy().transpose(0, 2, 3, 1).astype(np.uint8)
plt.figure(figsize=(15, 5))
plt.imshow(np.hstack(plot_images1))
plt.savefig('../assets/test_batch.png')
plt.show()
print(f"Labels :{labels1}")
# Out:
# Labels :tensor([0, 0, 0, 0, 0])

# %%
for images2, labels2 in val_loader:
    break
plot_images2 = (images2 * 255.0)
plot_images2 = plot_images2.numpy().transpose(0, 2, 3, 1).astype(np.uint8)
plt.figure(figsize=(15, 5))
plt.imshow(np.hstack(plot_images2))
plt.savefig('../assets/val_batch.png')
plt.show()
print(f"Labels :{labels2}")
# Out:
# Labels :tensor([0, 0, 0, 0, 0])
